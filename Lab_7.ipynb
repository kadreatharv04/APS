# %% [markdown]
# <a href="https://colab.research.google.com/github/kadreatharv04/Aps-lab/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy Knapsack Problem (Fractional)
# In this lab, we explore the Fractional Knapsack Problem, a fundamental optimization problem that demonstrates the Greedy Algorithmic Paradigm.
# We will implement it using greedy selection (based on value-to-weight ratio) and analyze its time and space complexity.

# %% [markdown]
# - Created by Dr. Ajay

# %% [markdown]
# # Problem Definition
# Given a set of
# n
# n items, each with:
# Value vi
# Weight wi
# A knapsack with maximum capacity **W**
#
# Goal: maximize total value that can be put in the knapsack.
# Constraint: You may take fractions of items.
#
# Greedy Strategy:
#
# *  Sort items by decreasing ratio vi/wi
# *  Select items fully until knapsack is full.
# *  Take fraction of the next item if capacity remains.

# %%
def fractional_knapsack(items, capacity):
    """
    Solves the Fractional Knapsack Problem using a greedy approach.

    Args:
        items (list of dict): A list of dictionaries, where each dictionary
                             represents an item with 'value' and 'weight' keys.
        capacity (float): The maximum capacity of the knapsack.

    Returns:
        tuple: A tuple containing the maximum total value and a list of
               (item_index, fraction_taken) for items included.
    """
    # Calculate value-to-weight ratio for each item and store original index
    for i, item in enumerate(items):
        item['ratio'] = item['value'] / item['weight']
        item['index'] = i

    # Sort items by ratio in descending order
    items.sort(key=lambda x: x['ratio'], reverse=True)

    total_value = 0.0
    knapsack_contents = []
    remaining_capacity = capacity

    for item in items:
        if remaining_capacity == 0:
            break

        if item['weight'] <= remaining_capacity:
            # Take the whole item
            total_value += item['value']
            knapsack_contents.append((item['index'], 1.0))
            remaining_capacity -= item['weight']
        else:
            # Take a fraction of the item
            fraction = remaining_capacity / item['weight']
            total_value += item['value'] * fraction
            knapsack_contents.append((item['index'], fraction))
            remaining_capacity = 0

    return total_value, knapsack_contents

# Example Usage:
items_example = [
    {'value': 60, 'weight': 10},
    {'value': 100, 'weight': 20},
    {'value': 120, 'weight': 30}
]
knapsack_capacity = 50

max_value, contents = fractional_knapsack(items_example, knapsack_capacity)

print(f"Items: {items_example}")
print(f"Knapsack Capacity: {knapsack_capacity}")
print(f"Maximum Value: {max_value}")
print("Knapsack Contents (item_index, fraction_taken):")
for item_idx, fraction in contents:
    print(f"  Item {item_idx} (Value: {items_example[item_idx]['value']}, Weight: {items_example[item_idx]['weight']}): {fraction * 100:.2f}% taken")

# Another example
items_example_2 = [
    {'value': 10, 'weight': 2},
    {'value': 5, 'weight': 3},
    {'value': 15, 'weight': 5},
    {'value': 7, 'weight': 7},
    {'value': 6, 'weight': 1}
]
knapsack_capacity_2 = 10

max_value_2, contents_2 = fractional_knapsack(items_example_2, knapsack_capacity_2)

print(f"\nItems: {items_example_2}")
print(f"Knapsack Capacity: {knapsack_capacity_2}")
print(f"Maximum Value: {max_value_2}")
print("Knapsack Contents (item_index, fraction_taken):")
for item_idx, fraction in contents_2:
    print(f"  Item {item_idx} (Value: {items_example_2[item_idx]['value']}, Weight: {items_example_2[item_idx]['weight']}): {fraction * 100:.2f}% taken")
# Out:
# Items: [{'value': 60, 'weight': 10, 'ratio': 6.0, 'index': 0}, {'value': 100, 'weight': 20, 'ratio': 5.0, 'index': 1}, {'value': 120, 'weight': 30, 'ratio': 4.0, 'index': 2}]
# Knapsack Capacity: 50
# Maximum Value: 240.0
# Knapsack Contents (item_index, fraction_taken):
#   Item 0 (Value: 60, Weight: 10): 100.00% taken
#   Item 1 (Value: 100, Weight: 20): 100.00% taken
#   Item 2 (Value: 120, Weight: 30): 66.67% taken
#
# Items: [{'value': 6, 'weight': 1, 'ratio': 6.0, 'index': 4}, {'value': 10, 'weight': 2, 'ratio': 5.0, 'index': 0}, {'value': 15, 'weight': 5, 'ratio': 3.0, 'index': 2}, {'value': 5, 'weight': 3, 'ratio': 1.6666666666666667, 'index': 1}, {'value': 7, 'weight': 7, 'ratio': 1.0, 'index': 3}]
# Knapsack Capacity: 10
# Maximum Value: 34.333333333333336
# Knapsack Contents (item_index, fraction_taken):
#   Item 4 (Value: 7, Weight: 7): 100.00% taken
#   Item 0 (Value: 6, Weight: 1): 100.00% taken
#   Item 2 (Value: 15, Weight: 5): 100.00% taken
#   Item 1 (Value: 10, Weight: 2): 66.67% taken

# %% [markdown]
# In this lab, we implement Huffman Coding, a greedy algorithm used for lossless data compression.
# It assigns variable-length binary codes to input symbols based on their frequencies, ensuring that more frequent symbols receive shorter codes and less frequent symbols receive longer codes.
#
# This algorithm constructs a binary tree (Huffman Tree) where each leaf node represents a character, and the path from the root to a leaf gives the character’s binary code.
#
# Use:
# Huffman Tree Construction using a Min-Priority Queue (Min-Heap).
# Code generation for each character.
# Encoding and decoding using the generated Huffman codes.
# Complexity analysis and comparison with fixed-length encoding.
#
# # Pseudocode:
# 1. Create a leaf node for each character and insert all nodes into a
# 2. min-heap by frequency.
#    *  While the heap has more than one node:
#    * Extract two nodes with the lowest frequencies.
#    * Create a new internal node with frequency = sum of the two.
#    *  Set the two extracted nodes as left and right children.
#    *  Insert the new node back into the min-heap.
# 3. The remaining node is the root of the Huffman Tree.
#
# 4. Traverse the tree:
#    * Assign 0 for left edge and 1 for right edge.
#    * The resulting paths from root to leaves give Huffman codes.

# %%
# write code for above
